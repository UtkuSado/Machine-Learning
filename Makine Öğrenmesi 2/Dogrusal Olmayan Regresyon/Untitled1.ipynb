# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
metre = [4.88, 7.75, 9.85, 12.05, 14.35, 16.75, 19.25, 21.85, 24.68, 27.62]
kilo = [43870, 26620, 20250, 15920, 12800, 10450, 8620, 7150, 5910, 4890]

# %%
plt.figure(figsize= (10,10))
plt.plot(kilo, metre)
plt.show();

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m

kilolar = []
metres = range(4,28)

for metre in metres:
    
    kilo = -21218*m.log(metre) + 71785
    kilolar.append(kilo)

plt.figure(figsize= (10,10))
plt.plot(metres, kilolar)
plt.show();

# %%
kilolar
# Out:
# [42370.60624575816,
#  37635.94637397326,
#  33767.44758191913,
#  30496.678457344366,
#  27663.409368637243,
#  25164.288918080092,
#  22928.74949685233,
#  20906.45810176417,
#  19060.250704798207,
#  17361.904533381115,
#  15789.481580223444,
#  14325.59083301331,
#  12956.212491516322,
#  11669.879265815209,
#  10457.092040959178,
#  9309.893740046471,
#  8221.552619731425,
#  7186.322916384408,
#  6199.2612246432545,
#  5256.083726415309,
#  4353.053827677286,
#  3486.89274794652,
#  2654.707656260187,
#  1853.933377120149]

# %%
-21218*m.log(6) + 71785
# Out:
# 33767.44758191913
